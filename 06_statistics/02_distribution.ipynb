# %% [markdown]
# # Data Distribution

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# creating the hisplot by using seaborn library
plt.figure(figsize = (10,6))
plt.xlabel("Total Bill")
plt.ylabel("Frequency")
plt.title('Histogram of the TOTAL BILL')
sns.histplot(df['total_bill'], kde = True)
plt.show()

# %% [markdown]
# #### **This is the right skewed histogram of the total bill in the dataset of tips**

# %%
plt.figure(figsize = (10,6))
sns.histplot(df['tip'], kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
plt.figure(figsize = (10,6))
plt.xlabel("Size")
plt.ylabel("Frequency")
plt.title('Histogram of the SIZE')
sns.histplot(df['size'], kde=True)
# Out:
# <Axes: title={'center': 'Histogram of the SIZE'}, xlabel='Size', ylabel='Frequency'>

# %%
df1= sns.load_dataset('titanic')
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
plt.figure(figsize = (10,6))
sns.histplot(df1['age'], kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize = (10,6))
sns.histplot(data= df1, x = 'fare', kde=True, bins = 50, hue='class')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
plt.figure(figsize = (10,6))
sns.histplot(data= df1, x = 'age', kde=True, bins = 50,)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize = (10,6))
sns.histplot(data= df1, x = 'age', kde=True, bins = 50, hue='who')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize = (10,6))
sns.boxplot(data= df1, x = 'age',hue='who')
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# ----
# # Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generating example datasets with different distributions
np.random.seed(0)  # For reproducibility

# Normal distribution data
normal_data = np.random.normal(loc=0, scale=1, size=1000)

# Uniform distribution data
uniform_data = np.random.uniform(low=-2, high=2, size=1000)

# Exponential distribution data
exponential_data = np.random.exponential(scale=1, size=1000)

# Plotting the distributions
plt.figure(figsize=(12, 8))

# Normal Distribution Plot
plt.subplot(3, 1, 1)
plt.hist(normal_data, bins=30, color='skyblue', alpha=0.7)
plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Uniform Distribution Plot
plt.subplot(3, 1, 2)
plt.hist(uniform_data, bins=30, color='lightgreen', alpha=0.7)
plt.title('Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Exponential Distribution Plot
plt.subplot(3, 1, 3)
plt.hist(exponential_data, bins=30, color='salmon', alpha=0.7)
plt.title('Exponential Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Q1: Why normal distribution is important in Data Science ?\
# Q2: How to normalize the data ?

# %% [markdown]
# ----
# # Skewness and Kurtosis

# %%
from scipy import stats

# %%
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data= df1, x = 'fare', kde=True, hue='class')
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
# find the kurtosis of fare 
stats.kurtosis(df1['fare'], fisher=False)
# Out:
# np.float64(36.20428925264474)

# %%
stats.skew(df1['fare'])
# Out:
# np.float64(4.7792532923723545)

# %%
sns.histplot(data = df1, x = 'fare', kde=True)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
import numpy as np
from scipy.stats import skew, kurtosis

# Generating the example data by using numpy
np.random.seed(0)
data = np.random.normal(0, 1, 1000)

# calculating skewness and kurtosis
data_skewness = skew(data)
data_kurtosis = kurtosis(data)

# Displaying the results
print(f'Skewness of the data:{data_skewness}')
print(f'Kurtosis of the data:{data_kurtosis}')
# Out:
# Skewness of the data:0.03385895323565712
# Kurtosis of the data:-0.0467663244783294

# %%
sns.histplot(data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
# shapiro wilk test to test the normality of the data
shapiro_test = stats.shapiro(data)
print(f"Shapiro-Wilk test statistic: {shapiro_test[0]}")
print(f"Shapiro-Wilk test p-value: {shapiro_test[1]}")
# Out:
# Shapiro-Wilk test statistic: 0.9985554728235057
# Shapiro-Wilk test p-value: 0.5912267898687746

# %%
df_third = df1[df1['class'] == 'Third']
stats.kurtosis(df_third['fare'], fisher=False)
# Out:
# np.float64(11.152944142950977)

# %%
sns.histplot(data = df1, x = 'fare', kde=True, hue='class', bins=30)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>
